# %% [markdown]
# <a href="https://colab.research.google.com/github/Adomino20040/sentiment-analysis-ml1/blob/main/script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url= 'https://raw.githubusercontent.com/Adomino20040/sentiment-analysis-ml1/main/Tweets.csv'
df = pd.read_csv(url)
df.head(100)
# Out:
#               tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0   570306133677760513           neutral                        1.0000
# 1   570301130888122368          positive                        0.3486
# 2   570301083672813571           neutral                        0.6837
# 3   570301031407624196          negative                        1.0000
# 4   570300817074462722          negative                        1.0000
# ..                 ...               ...                           ...
# 95  569910981868060673          negative                        1.0000
# 96  569909224521641984          negative                        1.0000
# 97  569907336485019648          negative                        1.0000
# 98  569896805611089920          negative                        1.0000
# 99  569894449620369408          negative                        1.0000
#
#              negativereason  negativereason_confidence         airline  \
# ...

# %%
df.info()
df.columns
df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
df.drop(columns=['airline_sentiment_gold', 'airline', 'name', 'user_timezone', 'tweet_location', 'tweet_created', 'tweet_coord', 'retweet_count', 'negativereason_gold','negativereason_confidence', 'negativereason'], inplace = True)

# %%
df.head(100)
# Out:
#               tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0   570306133677760513           neutral                        1.0000
# 1   570301130888122368          positive                        0.3486
# 2   570301083672813571           neutral                        0.6837
# 3   570301031407624196          negative                        1.0000
# 4   570300817074462722          negative                        1.0000
# ..                 ...               ...                           ...
# 95  569910981868060673          negative                        1.0000
# 96  569909224521641984          negative                        1.0000
# 97  569907336485019648          negative                        1.0000
# 98  569896805611089920          negative                        1.0000
# 99  569894449620369408          negative                        1.0000
#
#                                                  text
# 0                 @VirginAmerica What @dhepburn said.
# ...

# %%
import re

# removing unnecessary characters like puntuations, white-spaces and also urls

def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
df[['clean_text', 'text']].head(100)
# Out:
#                                            clean_text  \
# 0                                           what said
# 1   plus youve added commercials to the experience...
# 2   i didnt today must mean i need to take another...
# 3   its really aggressive to blast obnoxious enter...
# 4             and its a really big bad thing about it
# ..                                                ...
# 95  is it me or is your website down btw your new ...
# 96  i cant check in or add a bag your website isnt...
# 97  let 2 scanned in passengers leave the plane th...
# 98  what is your phone number i cant find who to c...
# 99  is anyone doing anything there today website i...
#
#                                                  text
# 0                 @VirginAmerica What @dhepburn said.
# 1   @VirginAmerica plus you've added commercials t...
# 2   @VirginAmerica I didn't today... Must mean I n...
# 3   @VirginAmerica it's really aggressive to blast...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initializing vectorizer (remove English stopwords, limiting max features for speed)
tfidf = TfidfVectorizer(stop_words='english', max_features=2000)

# Fit on training text and transform to numerical vectors
X_tfidf = tfidf.fit_transform(df['clean_text'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(df['airline_sentiment'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Split data (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42)

# Initialize and train model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7967896174863388
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      1889
#            1       0.67      0.50      0.57       580
#            2       0.78      0.60      0.68       459
#
#     accuracy                           0.80      2928
#    macro avg       0.76      0.68      0.71      2928
# weighted avg       0.79      0.80      0.79      2928

# %%
def predict_tweet_sentiment():
    tweet = input("Enter a tweet: ")
    cleaned = clean_text(tweet)
    vector = tfidf.transform([cleaned])
    pred_label = model.predict(vector)[0]
    sentiment = le.inverse_transform([pred_label])[0]
    print(f"Predicted sentiment: {sentiment}")

# %%
predict_tweet_sentiment()
# Out:
# Enter a tweet: it was more or less okay nothing special but just okay to get by
# Predicted sentiment: neutral
